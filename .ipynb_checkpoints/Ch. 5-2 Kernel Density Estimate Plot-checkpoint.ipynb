# %%
# KDE
import pandas as pd
movies = pd.read_csv('D:\\Users\\Minerva\\Programming\\Udemy\\Python A-Z Python For Data Science With Real Exercises\\6. Advanced Visualization\\MovieRatings.csv')
movies.columns = ['Film','Genre','RottenRating','AudienceRating','Budget','Year']
movies.head()
# Out:
#                     Film      Genre  RottenRating  AudienceRating  Budget  \
# 0  (500) Days of Summer      Comedy            87              81       8
# 1            10,000 B.C.  Adventure             9              44     105
# 2             12 Rounds      Action            30              52      20
# 3              127 Hours  Adventure            93              84      18
# 4              17 Again      Comedy            55              70      20
#
#    Year
# 0  2009
# 1  2008
# 2  2009
# 3  2010
# 4  2009

# %%
from matplotlib import pyplot as plt
import seaborn as sbn
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
vis1 = sbn.lmplot(data=movies, x='RottenRating', y='AudienceRating', fit_reg=False, hue='Genre', size=7, aspect=1.2)

# %%
k2 = sbn.kdeplot(movies.RottenRating, movies.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')

# %%
k1 = sbn.kdeplot(movies.RottenRating, movies.AudienceRating, cmap='Reds')
# Tip: smoother outline, add just outline with other one
k2 = sbn.kdeplot(movies.RottenRating, movies.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')

# %%
k3 = sbn.kdeplot(movies.Budget, movies.AudienceRating, cmap='Reds')
# Tip: smoother outline, add just outline with other one
k4 = sbn.kdeplot(movies.Budget, movies.AudienceRating, shade=True, shade_lowest=False, cmap='Reds')

# %%
# -----------------------------------------------------------------------------------------------------------
# Working with Subplots()

# %%
k5 = sbn.kdeplot(movies.Budget, movies.AudienceRating)

# %%
k6 = sbn.kdeplot(movies.Budget, movies.RottenRating)

# %%
f, axes = plt.subplots(nrows=1,ncols=2, figsize=(12,6), sharex=True, sharey=True)
k7 = sbn.kdeplot(movies.Budget, movies.AudienceRating, ax=axes[0])
k8 = sbn.kdeplot(movies.Budget, movies.RottenRating, ax=axes[1])
k7.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD14DD8>,
# ...
#       dtype=object)

# %%
f, axes = plt.subplots(nrows=2,ncols=2, figsize=(12,6), sharex=True, sharey=True)
k7 = sbn.kdeplot(movies.Budget, movies.AudienceRating, ax=axes[0,0])
k8 = sbn.kdeplot(movies.Budget, movies.RottenRating, ax=axes[0,1])
k7.set(xlim=(-20,160))
# Out:
# [(-20, 160)]
