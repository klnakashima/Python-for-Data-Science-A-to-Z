# %%
import pandas as pd
stats = pd.read_csv('D:\\Users\\Minerva\\Programming\\Udemy\\Python A-Z Python For Data Science With Real Exercises\\5. Data Frames\\P4-Demographic-Data.csv')

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
# Mathematic ops
result = stats.BirthRate * stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
# How to add a column
stats['MyCalc'] = result

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
# axis defaul is 0 which indicates dropping a row
stats = stats.drop('MyCalc', 1)

# %%
#------------------------------------------------------------------------------

# %%
# Filter Dataframes
# It's all about the rows
Filter = stats.InternetUsers < 2
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[Filter]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
Filter2 = stats.BirthRate > 40
stats[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
stats[stats.BirthRate < 10]
# Out:
#                 CountryName CountryCode  BirthRate  InternetUsers  \
# 9                   Austria         AUT      9.400        80.6188
# 16                 Bulgaria         BGR      9.200        53.0615
# 19   Bosnia and Herzegovina         BIH      9.062        57.7900
# 45                  Germany         DEU      8.500        84.1700
# 53                    Spain         ESP      9.100        71.6350
# 68                   Greece         GRC      8.500        59.8663
# 74     Hong Kong SAR, China         HKG      7.900        74.2000
# 76                  Croatia         HRV      9.400        66.7476
# 78                  Hungary         HUN      9.200        72.6439
# 86                    Italy         ITA      8.500        58.4593
# 89                    Japan         JPN      8.200        89.7100
# 95              Korea, Rep.         KOR      8.600        84.7700
# 102           Liechtenstein         LIE      9.200        93.8000
# ...

# %%
# stats[stats.BirthRate < 10 and stats.InternetUsers < 60] throws error
# Filter and Filter2 throws error. and compares two expected single boolean element

# %%
stats[Filter & Filter2]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
# can get aroung by using '&' and being explicit with ()&()
stats[(stats.BirthRate < 10) & (stats.InternetUsers < 60)]
# Out:
#                 CountryName CountryCode  BirthRate  InternetUsers  \
# 16                 Bulgaria         BGR      9.200        53.0615
# 19   Bosnia and Herzegovina         BIH      9.062        57.7900
# 68                   Greece         GRC      8.500        59.8663
# 86                    Italy         ITA      8.500        58.4593
# 146                 Romania         ROU      8.800        49.7645
# 157                  Serbia         SRB      9.200        51.5000
#
#              IncomeGroup
# 16   Upper middle income
# 19   Upper middle income
# 68           High income
# 86           High income
# 146  Upper middle income
# 157  Upper middle income

# %%
stats[(stats.IncomeGroup == "Low income")&(stats.InternetUsers > 10)]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 65   Gambia, The         GMB     42.525           14.0  Low income
# 77         Haiti         HTI     25.345           10.6  Low income
# 132        Nepal         NPL     20.923           13.3  Low income
# 158  South Sudan         SSD     37.126           14.1  Low income
# 178       Uganda         UGA     43.474           16.2  Low income
# 194     Zimbabwe         ZWE     35.715           18.5  Low income

# %%
# How to get unique categories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
# Ex// Find out everything about Malta
stats[stats.CountryName == "Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
#----------------------------------------------------------------------------

# %%
# Using .at() and .iat()
# .at for labels, integers treated as labels
# .iat for integer location

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[0,'BirthRate']
# Out:
# 10.244000000000002

# %%
stats.iat[1,0]
# Out:
# 'Afghanistan'

# %%
stats.at[1,'CountryName']
# Out:
# 'Afghanistan'

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# why we need .at:
sub = stats[::10]

# %%
sub
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
# interger counts down 10 rows
sub.iat[10,0]
# Out:
# 'Libya'

# %%
# label indexes to label 10 regardless of the fact it is in second row
sub.at[10,'CountryName']
# Out:
# 'Azerbaijan'
